# %% [markdown]
# This notebook plots subsets of ERA grids in order to inspect large scale forcing

# %%
require(raster)
# Out:
# Loading required package: raster
# Loading required package: sp

# %%
rst = stack("/home/joel/mnt/myserver/nas/sim/SIMS_JAN18/gcos_cor8/eraDat/SURF.nc", varname="tp")
# Out:
# Loading required namespace: ncdf4

# %%
st = which(names(rst)=="X2012.01.01.00.00.00")
ed = which(names(rst)=="X2012.03.01.00.00.00")

# %%
# read in shapefile
wfj = shapefile("/home/joel/mnt/myserver/nas/sim/SHAPEFILE_DOMAINS/wfj.shp")

# %%
# plot
plot(mean(rst[[st:ed]]))
plot(wfj, add=T)
# Out:
# Plot with title “”
